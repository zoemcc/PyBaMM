# %%
import pybamm
import pandas 
import matplotlib.pyplot as plt

# %%
data_1C = pandas.read_csv("kim_4C.csv", header=None)

# %%
plt.plot(data_1C[0], data_1C[1], color="r", linestyle=":")
plt.show()
